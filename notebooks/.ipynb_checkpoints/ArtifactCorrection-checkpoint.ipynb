# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from systole import import_ppg
from systole.detection import oxi_peaks, peak_replacement, artifact_removal
from systole.hrv import time_domain
from adtk.detector import QuantileAD, GeneralizedESDTestAD
from adtk.visualization import plot
from adtk.data import validate_series

# %% [markdown]
# Here, we describe the default method used to detect and remove artifacts and outliers in PPG recording. We use the [Anomaly Detection Toolkit](https://arundo-adtk.readthedocs-hosted.com/en/latest/index.html) to detect volatility changes in PPG recording and spikes in R-R time series.

# %%
oxi = import_ppg('1')[0, :]

# %% [markdown]
# # Find peaks

# %%
signal, peaks = oxi_peaks(oxi)

# Remove 3 consecutive beats
#peaks[np.where(peaks)[0][50:53]] = 0

# Remove 2 consecutive beats
#peaks[np.where(peaks)[0][100:101]] = 0

# Store into a Panda DataFrame
rr = np.diff(np.where(peaks))[0]
time = pd.to_datetime(np.cumsum(rr), unit='ms')
df = pd.DataFrame({'rr': rr}, index=time)
df = validate_series(df.rr)

# %% [markdown]
# Original time-serie

# %%
plot(df, ts_linewidth=1);

# %%
time_domain(rr)
# Out:
#      Values     Metric
# 0    872.00     MeanRR
# 1     70.80    MeanBPM
# 2    881.50   MedianRR
# 3     68.07  MedianBPM
# 4    137.00      MinRR
# 5     53.67     MinBPM
# 6   1118.00      MaxRR
# 7    437.96     MaxBPM
# 8    105.29       SDNN
# 9     72.09      RMSSD
# 10   105.00       nn50
# 11    27.70      pnn50

# %% [markdown]
# # Find outliers

# %% [markdown]
# We use quantile detection for to find outliers in the lower bound of the distribution (too short R-R interval, likely created by extra R peaks).

# %%
quantile_ad = QuantileAD(low=0.01)
anomalies = quantile_ad.fit_detect(df)

# %%
plot(df, anomaly_pred=anomalies, ts_linewidth=1, ap_markersize=5, ap_color='red', ap_marker_on_curve=True);

# %% [markdown]
# # Remove outliers

# %%
# Remove peqks in booleqn vector
rm_peaks = np.where(peaks)[0][1:][anomalies.values]
peaks[rm_peaks] = 0
new_rr = np.diff(np.where(peaks))[0]

# %%
# Create a new DataFrame
time = pd.to_datetime(np.cumsum(new_rr), unit='ms')
df = pd.DataFrame({'rr': new_rr}, index=time)
df = validate_series(df.rr)

# %% [markdown]
# R-R time-serie after low outliers removal

# %%
plot(df)

# %% [markdown]
# Here, we can see that this procedure also revealed a missing R peaks (at 3:00).

# %% [markdown]
# Find outliers in the upper bound (resulting in a missing R peaks). Here, we use a generalized ESD test.

# %%
quantile_ad = GeneralizedESDTestAD()
anomalies = quantile_ad.fit_detect(df)

# %%
plot(df, anomaly_pred=anomalies, ts_linewidth=1, ap_markersize=5, ap_color='red', ap_marker_on_curve=True);

# %% [markdown]
# Here, we will just add a skipe equidistant for the outlying peak and the previous one.

# %%
final = []
for outlier in np.where(anomalies.values)[0]:
    new_peaks, npeaks = peak_replacement(peaks, outlier)
    final.append(new_peaks)

# %%
for f in final:
    peaks = np.logical_or(peaks, f)

# %% [markdown]
# R-R time-serie after outlier correction

# %%
new_rr = np.diff(np.where(peaks))[0]
# Create a new DataFrame
time = pd.to_datetime(np.cumsum(new_rr), unit='ms')
df = pd.DataFrame({'rr': new_rr}, index=time)
df = validate_series(df.rr)
plot(df)

# %%
time_domain(new_rr)
# Out:
#      Values     Metric
# 0    879.00     MeanRR
# 1     68.94    MeanBPM
# 2    882.00   MedianRR
# 3     68.03  MedianBPM
# 4    664.00      MinRR
# 5     53.67     MinBPM
# 6   1118.00      MaxRR
# 7     90.36     MaxBPM
# 8     85.67       SDNN
# 9     46.81      RMSSD
# 10    99.00       nn50
# 11    26.33      pnn50

# %% [markdown]
# As we can see, a few outliers can affect significantly the estimation of HRV metrics influenced by vagally mediated variability.

# %%
quantile_ad = GeneralizedESDTestAD()
anomalies = quantile_ad.fit_detect(df)
plot(df, anomaly_pred=anomalies, ts_linewidth=1, ap_markersize=5, ap_color='red', ap_marker_on_curve=True);

# %% [markdown]
# # Test functions

# %% [markdown]
# The procedure prviously describe is implemented in the artifact_removal() function.

# %% [markdown]
# ## Test with extrabeats

# %%
#signal, peaks = oxi_peaks(oxi)
time_domain(np.diff(np.where(peaks)[0]))
# Out:
#      Values     Metric
# 0    879.00     MeanRR
# 1     68.94    MeanBPM
# 2    882.00   MedianRR
# 3     68.03  MedianBPM
# 4    664.00      MinRR
# 5     53.67     MinBPM
# 6   1118.00      MaxRR
# 7     90.36     MaxBPM
# 8     85.67       SDNN
# 9     46.81      RMSSD
# 10    99.00       nn50
# 11    26.33      pnn50

# %%
rms = []
for i in range(100):
    noisy_peaks = peaks.copy()
    
    # Add extra beats (n=5)
    idx = np.random.choice(np.where(noisy_peaks==0)[0], size=5)
    noisy_peaks[idx] = 1
    
    # Apply artifact correction
    clean_peaks, per = artifact_removal(noisy_peaks)
    stats = time_domain(np.diff(np.where(clean_peaks)[0]))
    rms.append(stats.Values[stats.Metric=='RMSSD'].iloc[0])

# %%
plt.hist(rms, bins=30)
plt.axvline(x=46.81, color='r', linestyle='--')

# %%
plt.figure(figsize=(12, 4))
plt.plot(np.cumsum(np.diff(np.where(peaks)[0]))/1000,
         np.diff(np.where(peaks)[0]))
plt.plot(np.cumsum(np.diff(np.where(clean_peaks)[0]))/1000,
         np.diff(np.where(clean_peaks)[0]), 'r')

# %%
plt.figure(figsize=(12, 4))
plt.plot(np.diff(np.diff(np.where(clean_peaks)[0])), 'r')

# %%
from scipy import interpolate
rr = np.diff(np.where(clean_peaks)[0])
time = np.arange(0, len(rr))

# Remove value
rr_mising = np.delete(rr, 50)
time_missing = np.delete(time, 50)

f = interpolate.interp1d(time_missing, rr_mising, kind='cubic')
new_rr = f(time)

# %%
plt.figure(figsize=(12, 4))
plt.plot(time, new_rr, 'ro')
plt.plot(time_missing, rr_mising, 'bo')
plt.xlim(25, 75)
# Out:
# (25, 75)

# %%
plt.plot(np.diff(np.where(noisy_peaks)[0]))

# %%
np.where(np.diff(np.where(noisy_peaks)[0]) > 1250)
# Out:
# (array([ 75, 304], dtype=int64),)

# %%
plt.plot(np.diff(np.where(noisy_peaks)[0]))

plt.plot(np.diff(np.where(final_peaks)[0]))
plt.xlim(50, 100)
# Out:
# (50, 100)

# %%
def peak_replacement(peaks, outlier, kind='cubic'):
    """Given the index of a detected peak, will add the requiered number of R
    peaks to minimize signal standard deviation.

    Parameters
    ----------
    rr: boolean array
        Indexes of R peaks.
    outlier: int
        Index of detected outlier
    kind: str
        The kind of interpolation (`scipy.interpolate.intrp1d()` parameter).
        Default is 'cubic'.

    Return
    ------
    new_rr: boolean array
        New indexes vector with added spikes.
    npeaks: int
        Number of peaks added [1-5].
    """
    peaks = np.where(peaks)[0]
    time = np.arange(0, len(peaks))
    
    # Replace n peaks by minimizing signal standard deviation
    min_std = np.inf
    for i in range(5):
        
        this_time = time.copy()
        # Shift the time points according to the number of added peaks
        this_time[outlier:] = this_time[outlier:] + i
    
        # Interpolate signal
        f = interpolate.interp1d(time_missing, rr_mising, kind=kind)
        
        # Find new value(s) for missing point(s)
        new_rr = f(np.arange(0, this_time[-1], 1))
        new_rr = new_rr.astype(int)

        # Compute signal std to measure effect of peak replacement
        this_std = np.std(new_rr)
        if min_std > this_std:
            min_std = this_std
            final_peaks = np.zeros(len(peaks))
            final_peaks[np.cumsum(new_rr)] = 1
            npeaks = i

    return final_peaks, npeaks

# %% [markdown]
# # 3 Categories of artifacts

# %% [markdown]
# ## Correcting a missing peak

# %% [markdown]
# Remove one peak in R-R time serie.

# %%
plt.plot(np.diff(np.where(peaks)[0]))

# %%
idx = np.random.choice(np.where(peaks)[0])
peaks[idx] = 0
plt.plot(np.diff(np.where(peaks)[0]))

# %% [markdown]
# Here, we will assuma that one peaks is missing, and will thus remove the outlier R-R interval and interpolate 2 new values.

# %% [markdown]
# # References
#
# Rincon Soler, A. I., Silva, L. E. V., Fazan, R., Jr., & Murta, L. O., Jr. (2018). The impact of artifact correction methods of RR series on heart rate variability parameters. Journal of Applied Physiology, 124(3), 646–652. https://doi.org/10.1152/japplphysiol.00927.2016
#
# Al Osman, H., Eid, M., & El Saddik, A. (2015). A Pattern-Based Windowed Impulse Rejection Filter for Nonpathological HRV Artifacts Correction. IEEE Transactions on Instrumentation and Measurement, 64(7), 1944–1957. https://doi.org/10.1109/tim.2014.2370496
