# %%
from ect.recording import Oximeter
import serial
import matplotlib.pypl

# %%
ser = serial.Serial('COM4',
             baudrate=9600,
             timeout=1/75,
             stopbits=1,
             parity=serial.PARITY_NONE)

# %%
# Open seral port for Oximeter
oxi = Oximeter(serial=ser, sfreq=75)
oxi.setup()

# %%
oxi.read(duration=10)

# %%
oxi.plot()
plt.savefig('recording.png', dpi=600)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-286a7dd9fd45> in <module>
#       1 oxi.plot()
# ----> 2 plt.savefig('recording.png', dpi=600)
#
# NameError: name 'plt' is not defined
